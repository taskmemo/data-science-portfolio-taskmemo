# %%
import numpy as np
import pandas as pd
import scipy as sp
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import seaborn as sns

from sklearn import linear_model

# %% [markdown]
# ## loading data

# %%
df_math = pd.read_csv("data/student-mat.csv", encoding='utf-8', sep=';')
df_por = pd.read_csv("data/student-por.csv", encoding='utf-8', sep=';')

# %%
df_math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df_math.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_math.describe(include='all')
# Out:
#        school  sex         age address famsize Pstatus        Medu  \
# count     395  395  395.000000     395     395     395  395.000000
# unique      2    2         NaN       2       2       2         NaN
# top        GP    F         NaN       U     GT3       T         NaN
# freq      349  208         NaN     307     281     354         NaN
# mean      NaN  NaN   16.696203     NaN     NaN     NaN    2.749367
# std       NaN  NaN    1.276043     NaN     NaN     NaN    1.094735
# min       NaN  NaN   15.000000     NaN     NaN     NaN    0.000000
# 25%       NaN  NaN   16.000000     NaN     NaN     NaN    2.000000
# 50%       NaN  NaN   17.000000     NaN     NaN     NaN    3.000000
# 75%       NaN  NaN   18.000000     NaN     NaN     NaN    4.000000
# max       NaN  NaN   22.000000     NaN     NaN     NaN    4.000000
#
#               Fedu   Mjob   Fjob  ...      famrel    freetime       goout  \
# count   395.000000    395    395  ...  395.000000  395.000000  395.000000
# ...

# %% [markdown]
# ## EDA

# %%
sns.pairplot(df_math[["Dalc", "Walc", "G1", "G3"]])

# %% [markdown]
# ## regression analysis

# %%
plt.plot(df_math["G1"], df_math["G3"], 'o')
plt.xlabel("G1 grade")
plt.ylabel("G3 grade")
plt.show()

# %%
# create linear regression object
reg = linear_model.LinearRegression()

x = df_math["G1"].to_numpy().reshape(-1, 1)
y = df_math["G3"].to_numpy()

# train the model using the training sets
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', reg.coef_)
print('Intercept: \n', reg.intercept_)
# Out:
# Coefficients:
#  [1.10625609]
# Intercept:
#  -1.652803828800458

# %%
plt.scatter(x, y, color='blue')
plt.xlabel("G1 grade")
plt.ylabel("G3 grade")

plt.plot(x, reg.predict(x), color='red')

a = reg.coef_[0]
b = reg.intercept_

x_pos = float(x.min())
y_pos = float(y.max())

plt.text(
    x_pos, y_pos,
    f"y = {a:.2f}x + {b:.2f}",
    fontsize=12, color='red'
)
plt.grid(True)

# %%
#R-squared
r2 = reg.score(x,y)
print(f"R-squared: {r2:.4f}")
# Out:
# R-squared: 0.6424

# %% [markdown]
# ## practice

# %%
df_por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df_por.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df_por.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
sns.pairplot(df_por[["G1", "G3"]])

# %% [markdown]
# there is a high correlation between G1 and G3.

# %%
reg = linear_model.LinearRegression()
x = df_por["G1"].to_numpy().reshape(-1, 1)
y = df_por["G3"].to_numpy()

reg.fit(x,y)
print('Coefficients:', reg.coef_[0])
print('Intercept:', reg.intercept_)
print(f"R-squared: {reg.score(x,y): .4f}")
# Out:
# Coefficients: 0.9725008692272119
# Intercept: 0.8203984121064511
# R-squared:  0.6829

# %%
# show plot scatter plot with regression line
plt.scatter(x,y, color='blue')
plt.xlabel('G1 grade')
plt.ylabel('G3 grade')

plt.plot(x, reg.predict(x), color='red')

a = reg.coef_[0]
b = reg.intercept_

x_pos = float(x.min())
y_pos = float(y.max())

plt.text(
    x_pos, y_pos,
    f"y = {a:.2f}x + {b:.2f}",
    fontsize=12, color='red'
)
plt.show()
